// %%
// purpose of this notebook:
// to find coins that have the highest likelihood of going up with the least amount of new capital inflows

// data we need:
// 1. total coin market cap ovet time
// 2. a list of coins
// 3. the market cap of those coins over

// what we do with that data:
// * convert the coin market caps of each coin into a dominance %
// * calculate the time since the last the coin last hit peak dominance
// * multiply the dominance % by the time since the last peak
// * sort the coins in descending order of the product of the dominance % and the time since the last peak

#r "nuget: FSharp.Data"
#r "nuget: Microsoft.Data.Analysis"

open FSharp.Data

type BinanceExchangeInfo = JsonProvider<"https://api.binance.com/api/v3/exchangeInfo">
type PriceStream = JsonProvider<"https://api.binance.com/api/v3/klines?symbol=1INCHDOWNUSDT&interval=1d">
type CoinGecko = JsonProvider<"https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=250&page=1&sparkline=false">

let show a =
    printf "%A\n" a

type MarketCap = 
    { Symbol: string
    ; MarketCap: int64
    ; Rank: int }

let geckoByPage page = 
    CoinGecko.Load("https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=250&page=" + page.ToString() + "&sparkline=false")

let gecko = 
    (List.foldl (\acc page -> 
        acc + geckoByPage page) 
        (List.empty) 
        (List.range 1 10))

let geckoSub =
    gecko
    |> Array.map (fun x -> { Symbol = x.Symbol; MarketCap = x.MarketCap; Rank = x.MarketCapRank })

show geckoSub

let exchInfo = BinanceExchangeInfo.Load("https://api.binance.com/api/v3/exchangeInfo")

let assets = 
    exchInfo.Symbols 
    |> Array.filter (fun x-> x.QuoteAsset.IndexOf("USDT") <> -1 )
    |> Array.filter (fun x-> x.BaseAsset.IndexOf("UP") = -1 && x.BaseAsset.IndexOf("DOWN") = -1) 
    |> Array.map (fun x -> x.Symbol) 
    |> Array.sort
    //|> Array.take 20

show assets.Length

type Candle = 
    { Time : uint64
    ; Open : decimal
    ; High:  decimal
    ; Low : decimal
    ; Close: decimal }
    
let makeCandle (assetRow:(decimal array)) =
    { Time = (uint64)assetRow.[0]
    ; Open = assetRow.[1]
    ; High = assetRow.[2]
    ; Low = assetRow.[3]
    ; Close = assetRow.[4] }

let assetHistory symbol (limit:uint64) =
    PriceStream.Load("https://api.binance.com/api/v3/klines?symbol=" + symbol + "&interval=1d&limit=" + limit.ToString())
    |> Array.map makeCandle

let ethHistory = 
    assetHistory "ETHUSDT" 1000UL

let ethPricedAssetHistory limit symbol = 
    let asset = assetHistory symbol limit
    let eth = 
        ethHistory
        |> Array.skip (ethHistory.Length - asset.Length)

    asset
    |> Array.zip eth
    |> Array.map (fun (ethRow, assetRow) -> 
        { Time = assetRow.Time
        ; Open = assetRow.Open / ethRow.Open
        ; High = assetRow.High / ethRow.High
        ; Low = assetRow.Low / ethRow.Low
        ; Close = assetRow.Close / ethRow.Close })

let ath assetHistory = 
    assetHistory 
    |> Array.maxBy (fun x -> x.High)

let timeSinceLastAth now assetHistory =
    let lastAth = (ath assetHistory).Time
    now - lastAth

let daysSinceLastAth now assetHistory =
    (timeSinceLastAth now assetHistory) / (24UL * 60UL * 60UL) / 1000UL

"BTCUSDT" |> (ethPricedAssetHistory 1000UL) |> (daysSinceLastAth ethHistory.[ethHistory.Length - 1].Time)

type assetAthDays = 
    { Asset: string
    ; MarketCap: int64
    ; Rank: int
    ; DaysSinceLastAth: uint64
    ; Order: float }

let allDaysSinceLastAth limit assetList = 
    assetList
    |> Array.Parallel.map (fun (asset:string) -> 
        show asset

        let ast = asset.Replace("USDT", "").ToLowerInvariant()
        
        let cap = 
            geckoSub 
            |> Array.filter (fun x -> x.Symbol = ast.ToLowerInvariant())
            |> Array.sumBy (fun x -> x.MarketCap)

        let rank = 
            geckoSub 
            |> Array.filter (fun x -> x.Symbol = ast.ToLowerInvariant())
            |> Array.sumBy (fun x -> x.Rank)

        let dsath = 
            asset 
            |> ethPricedAssetHistory limit 
            |> daysSinceLastAth ethHistory.[ethHistory.Length - 1].Time

        let order = 
            // ((float(dsath) + 1.0) * Math.Sqrt(float(cap) + 1.0))
            (float(dsath) + 1.0) / float(rank) 

        { Asset = ast
        ; MarketCap = cap / 1000000L
        ; Rank = rank
        ; DaysSinceLastAth = dsath
        ; Order = order })

assets  
|> Array.take assets.Length
|> allDaysSinceLastAth 1000UL
|> Array.filter (fun x -> x.MarketCap <> 0L)
|> Array.sortByDescending (fun x -> x.Order)
//|> Array.skip 20
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>FSharp.Data, 4.2.3</span></li><li><span>Microsoft.Data.Analysis, 0.18.0</span></li></ul></div></div>
// [|{ Symbol = "cnd"
//     MarketCap = 27706123L
//     Rank = 751 }; { Symbol = "tulip"
//                     MarketCap = 27584004L
//                     Rank = 752 }; { Symbol = "zano"
//                                     MarketCap = 27495282L
//                                     Rank = 753 }; { Symbol = "cell"
//                                                     MarketCap = 27447298L
//                                                     Rank = 754 };
//   { Symbol = "ppt"
//     MarketCap = 27411010L
//     Rank = 755 }; { Symbol = "ousd"
//                     MarketCap = 27396247L
//                     Rank = 756 }; { Symbol = "wtc"
//                                     MarketCap = 27392043L
//                                     Rank = 757 }; { Symbol = "mtsla"
//                                                     MarketCap = 27107440L
//                                                     Rank = 759 };
//   { Symbol = "lpool"
//     MarketCap = 27081247L
//     Rank = 760 }; { Symbol = "dpet"
//                     MarketCap = 27015624L
//                     Rank = 758 }; { Symbol = "arnx"
//                                     MarketCap = 26905295L
//                                     Rank = 761 }; { Symbol = "mslv"
//                                                     MarketCap = 26806741L
//                                                     Rank = 762 };
//   { Symbol = "nif"
//     MarketCap = 26794088L
//     Rank = 763 }; { Symbol = "foam"
//                     MarketCap = 26638773L
//                     Rank = 764 }; { Symbol = "deri"
//                                     MarketCap = 26626249L
//                                     Rank = 765 }; { Symbol = "sale"
//                                                     MarketCap = 26546372L
//                                                     Rank = 766 };
//   { Symbol = "lz"
//     MarketCap = 26542213L
//     Rank = 768 }; { Symbol = "cube"
//                     MarketCap = 26534431L
//                     Rank = 767 }; { Symbol = "maapl"
//                                     MarketCap = 26502773L
//                                     Rank = 769 }; { Symbol = "matter"
//                                                     MarketCap = 26483398L
//                                                     Rank = 770 };
//   { Symbol = "route"
//     MarketCap = 26374929L
//     Rank = 771 }; { Symbol = "mamzn"
//                     MarketCap = 26331129L
//                     Rank = 772 }; { Symbol = "mnflx"
//                                     MarketCap = 26213503L
//                                     Rank = 773 }; { Symbol = "dxl"
//                                                     MarketCap = 26122127L
//                                                     Rank = 774 };
//   { Symbol = "vvsp"
//     MarketCap = 25999293L
//     Rank = 788 }; { Symbol = "dashd"
//                     MarketCap = 25965931L
//                     Rank = 775 }; { Symbol = "dfy"
//                                     MarketCap = 25876918L
//                                     Rank = 776 }; { Symbol = "val"
//                                                     MarketCap = 25866897L
//                                                     Rank = 777 };
//   { Symbol = "ult"
//     MarketCap = 25859926L
//     Rank = 778 }; { Symbol = "sky"
//                     MarketCap = 25767800L
//                     Rank = 779 }; { Symbol = "gel"
//                                     MarketCap = 25622257L
//                                     Rank = 781 }; { Symbol = "musd"
//                                                     MarketCap = 25593939L
//                                                     Rank = 780 };
//   { Symbol = "mix"
//     MarketCap = 25516136L
//     Rank = 782 }; { Symbol = "lbc"
//                     MarketCap = 25358976L
//                     Rank = 783 }; { Symbol = "mtwtr"
//                                     MarketCap = 25286963L
//                                     Rank = 785 }; { Symbol = "swth"
//                                                     MarketCap = 25221949L
//                                                     Rank = 786 };
//   { Symbol = "thn"
//     MarketCap = 25090236L
//     Rank = 784 }; { Symbol = "cocos"
//                     MarketCap = 24844016L
//                     Rank = 787 }; { Symbol = "muso"
//                                     MarketCap = 24732388L
//                                     Rank = 789 }; { Symbol = "unic"
//                                                     MarketCap = 24713497L
//                                                     Rank = 790 };
//   { Symbol = "gto"
//     MarketCap = 24638955L
//     Rank = 791 }; { Symbol = "bank"
//                     MarketCap = 24552790L
//                     Rank = 792 }; { Symbol = "nest"
//                                     MarketCap = 24242258L
//                                     Rank = 793 }; { Symbol = "gero"
//                                                     MarketCap = 24134430L
//                                                     Rank = 796 };
//   { Symbol = "cvnt"
//     MarketCap = 24132936L
//     Rank = 795 }; { Symbol = "naft"
//                     MarketCap = 24061861L
//                     Rank = 794 }; { Symbol = "dvf"
//                                     MarketCap = 23892629L
//                                     Rank = 798 }; { Symbol = "dxd"
//                                                     MarketCap = 23783642L
//                                                     Rank = 799 };
//   { Symbol = "ring"
//     MarketCap = 23730258L
//     Rank = 800 }; { Symbol = "hbc"
//                     MarketCap = 23713624L
//                     Rank = 801 }; { Symbol = "govi"
//                                     MarketCap = 23580426L
//                                     Rank = 802 }; { Symbol = "like"
//                                                     MarketCap = 23524479L
//                                                     Rank = 803 };
//   { Symbol = "pendle"
//     MarketCap = 23483401L
//     Rank = 804 }; { Symbol = "mdt"
//                     MarketCap = 23358129L
//                     Rank = 805 }; { Symbol = "polk"
//                                     MarketCap = 23355564L
//                                     Rank = 806 }; { Symbol = "lith"
//                                                     MarketCap = 23314685L
//                                                     Rank = 809 };
//   { Symbol = "arcx"
//     MarketCap = 23294693L
//     Rank = 808 }; { Symbol = "mork"
//                     MarketCap = 23203672L
//                     Rank = 807 }; { Symbol = "pop"
//                                     MarketCap = 23161706L
//                                     Rank = 811 }; { Symbol = "nebl"
//                                                     MarketCap = 23142907L
//                                                     Rank = 812 };
//   { Symbol = "stos"
//     MarketCap = 23095082L
//     Rank = 810 }; { Symbol = "spirit"
//                     MarketCap = 22963152L
//                     Rank = 813 }; { Symbol = "bpt"
//                                     MarketCap = 22844870L
//                                     Rank = 797 }; { Symbol = "mitx"
//                                                     MarketCap = 22818865L
//                                                     Rank = 814 };
//   { Symbol = "key"
//     MarketCap = 22637106L
//     Rank = 815 }; { Symbol = "sku"
//                     MarketCap = 22631929L
//                     Rank = 817 }; { Symbol = "buy"
//                                     MarketCap = 22629937L
//                                     Rank = 816 }; { Symbol = "maki"
//                                                     MarketCap = 22614494L
//                                                     Rank = 820 };
//   { Symbol = "sha"
//     MarketCap = 22528290L
//     Rank = 818 }; { Symbol = "nex"
//                     MarketCap = 22482784L
//                     Rank = 819 }; { Symbol = "xcur"
//                                     MarketCap = 22355372L
//                                     Rank = 821 }; { Symbol = "ads"
//                                                     MarketCap = 22248581L
//                                                     Rank = 822 };
//   { Symbol = "bao"
//     MarketCap = 22045385L
//     Rank = 823 }; { Symbol = "jup"
//                     MarketCap = 22044122L
//                     Rank = 824 }; { Symbol = "armor"
//                                     MarketCap = 21990358L
//                                     Rank = 825 }; { Symbol = "bean"
//                                                     MarketCap = 21968214L
//                                                     Rank = 826 };
//   { Symbol = "poolz"
//     MarketCap = 21900894L
//     Rank = 827 }; { Symbol = "spec"
//                     MarketCap = 21813229L
//                     Rank = 828 }; { Symbol = "bmi"
//                                     MarketCap = 21734668L
//                                     Rank = 829 }; { Symbol = "time"
//                                                     MarketCap = 21633699L
//                                                     Rank = 830 };
//   { Symbol = "mvi"
//     MarketCap = 21555551L
//     Rank = 831 }; { Symbol = "bmc"
//                     MarketCap = 21187245L
//                     Rank = 833 }; { Symbol = "c3"
//                                     MarketCap = 21140542L
//                                     Rank = 832 }; { Symbol = "bz"
//                                                     MarketCap = 21100991L
//                                                     Rank = 834 };
//   { Symbol = "gbyte"
//     MarketCap = 21064794L
//     Rank = 835 }; { Symbol = "xmon"
//                     MarketCap = 21026582L
//                     Rank = 836 }; { Symbol = "gfarm2"
//                                     MarketCap = 21013431L
//                                     Rank = 837 }; { Symbol = "ppay"
//                                                     MarketCap = 20886686L
//                                                     Rank = 838 };
//   { Symbol = "kccpad"
//     MarketCap = 20866173L
//     Rank = 839 }; { Symbol = "samo"
//                     MarketCap = 20697186L
//                     Rank = 840 }; { Symbol = "dafi"
//                                     MarketCap = 20660594L
//                                     Rank = 841 }; { Symbol = "mbaba"
//                                                     MarketCap = 20645655L
//                                                     Rank = 842 };
//   { Symbol = "bscx"
//     MarketCap = 20519782L
//     Rank = 843 }; { Symbol = "ppc"
//                     MarketCap = 20499244L
//                     Rank = 844 }; { Symbol = "pib"
//                                     MarketCap = 20483383L
//                                     Rank = 845 }; { Symbol = "zb"
//                                                     MarketCap = 20465472L
//                                                     Rank = 846 };
//   { Symbol = "lamb"
//     MarketCap = 20347660L
//     Rank = 847 }; { Symbol = "insur"
//                     MarketCap = 20234878L
//                     Rank = 848 }; { Symbol = "tarot"
//                                     MarketCap = 20110546L
//                                     Rank = 849 }; { Symbol = "axel"
//                                                     MarketCap = 19986325L
//                                                     Rank = 850 }; ...|]
// 295
// "1INCHUSDT"
// "BEARUSDT"
// "DAIUSDT"
// "C98USDT"
// "KEEPUSDT"
// "NMRUSDT"
// "STRAXUSDT"
// "TRXUSDT"
// "YFIIUSDT"
// "FIROUSDT"
// "BELUSDT"
// "CAKEUSDT"
// "HBARUSDT"
// "KEYUSDT"
// "NPXSUSDT"
// "STXUSDT"
// "WAXPUSDT"
// "ATOMUSDT"
// "EGLDUSDT"
// "MATICUSDT"
// "AAVEUSDT"
// "WAVESUSDT"
// "DASHUSDT"
// "MBLUSDT"
// "RSRUSDT"
// "YFIUSDT"
// "FIOUSDT"
// "PHAUSDT"
// "ELFUSDT"
// "TUSDUSDT"
// "ROSEUSDT"
// "PNTUSDT"
// "AUDIOUSDT"
// "HARDUSDT"
// "ACMUSDT"
// "AUDUSDT"
// "KLAYUSDT"
// "FISUSDT"
// "BKRWUSDT"
// "DATAUSDT"
// "NULSUSDT"
// "SUNUSDT"
// "ENJUSDT"
// "CELOUSDT"
// "RUNEUSDT"
// "MBOXUSDT"
// "HCUSDT"
// "POLSUSDT"
// "BLZUSDT"
// "ADAUSDT"
// "TVKUSDT"
// "AUTOUSDT"
// "WINGUSDT"
// "YGGUSDT"
// "CELRUSDT"
// "DCRUSDT"
// "EOSBEARUSDT"
// "FLMUSDT"
// "HIVEUSDT"
// "BNBBEARUSDT"
// "AIONUSDT"
// "WINUSDT"
// "NUUSDT"
// "POLYUSDT"
// "EOSBULLUSDT"
// "FLOWUSDT"
// "OGNUSDT"
// "ZECUSDT"
// "RVNUSDT"
// "TWTUSDT"
// "PSGUSDT"
// "AVAUSDT"
// "UNFIUSDT"
// "FORUSDT"
// "HNTUSDT"
// "ZILUSDT"
// "BNBUSDT"
// "CFXUSDT"
// "KMDUSDT"
// "EPSUSDT"
// "DEGOUSDT"
// "SUSDUSDT"
// "KSMUSDT"
// "ALGOUSDT"
// "CHZUSDT"
// "MINAUSDT"
// "AXSUSDT"
// "WRXUSDT"
// "FTTUSDT"
// "LINAUSDT"
// "QNTUSDT"
// "CLVUSDT"
// "BAKEUSDT"
// "IDEXUSDT"
// "ICPUSDT"
// "MCOUSDT"
// "XECUSDT"
// "ERNUSDT"
// "BONDUSDT"
// "SCUSDT"
// "USDCUSDT"
// "BANDUSDT"
// "SXPUSDT"
// "OMGUSDT"
// "ANKRUSDT"
// "BTCUSDT"
// "SHIBUSDT"
// "MDXUSDT"
// "DEXEUSDT"
// "COMPUSDT"
// "ALPACAUSDT"
// "TCTUSDT"
// "DGBUSDT"
// "ARDRUSDT"
// "ETHBEARUSDT"
// "DNTUSDT"
// "GALAUSDT"
// "INJUSDT"
// "LITUSDT"
// "MITHUSDT""DODOUSDT"
// "SLPUSDT"
// "XLMUSDT"
// "ASRUSDT"
// "BATUSDT"
// "BTSUSDT"
// "MKRUSDT"
// "LPTUSDT"
// "GHSTUSDT"
// "ONGUSDT"
// "RAMPUSDT"
// "ARUSDT"
// "QUICKUSDT"
// "ETHUSDT"
// "IOTAUSDT"
// "THETAUSDT"
// "COTIUSDT"
// "ONEUSDT"
//
// "USDSBUSDT"
// "SNXUSDT"
// "TKOUSDT"
// "PUNDIXUSDT"
// "AKROUSDT"
// "WNXMUSDT"
// "PONDUSDT"
// "EOSUSDT"
// "FORTHUSDT"
// "OCEANUSDT"
// "FTMUSDT"
// "ERDUSDT"
// "DENTUSDT"
// "CHRUSDT"
// "UMAUSDT"
// "AVAXUSDT"
// "UNIUSDT"
// "HOTUSDT"
// "KNCUSDT"
// "OGUSDT"
// "SANDUSDT"
// "BNTUSDT"
// "ZENUSDT"
// "MIRUSDT"
// "LENDUSDT"
// "ALICEUSDT"
// "BADGERUSDT"
// "FUNUSDT"
// "WTCUSDT"
// "USDSUSDT"
// "XMRUSDT"
// "ATAUSDT"
// "ATMUSDT"
// "BCCUSDT"
// "BTTUSDT"
// "CRVUSDT"
// "DOGEUSDT"
// "EURUSDT"
// "GNOUSDT"
// "IOTXUSDT"
// "ILVUSDT"
// "XEMUSDT"
// "BTCSTUSDT"
// "LINKUSDT"
// "MDTUSDT"
// "USDPUSDT"
// "ETCUSDT"
// "SFPUSDT"
// "SKLUSDT"
// "COCOSUSDT"
// "ALPHAUSDT"
// "MFTUSDT"
// "IOSTUSDT"
// "TFUELUSDT"
// "COSUSDT"
// "DOCKUSDT"
// "BNBBULLUSDT"
// "SUSHIUSDT"
// "BCHABCUSDT"
// "SYSUSDT""DIAUSDT"
// "ARPAUSDT"
//
// "CTKUSDT"
// "OMUSDT"
// "ONTUSDT"
// "ZRXUSDT"
// "BTGUSDT"
// "UTKUSDT"
// "BCHUSDT"
// "MLNUSDT"
// "LRCUSDT"
// "RAYUSDT"
// "RENUSDT"
// "GRTUSDT"
// "XRPBEARUSDT"
// "DOTUSDT"
// "NANOUSDT"
// "TLMUSDT"
// "BULLUSDT"
// "ETHBULLUSDT"
// "SOLUSDT"
// "CKBUSDT"
// "GBPUSDT"
// "QTUMUSDT"
