// %%
// purpose of this notebook:
// to find coins that have the highest likelihood of going up with the least amount of new capital inflows

// data we need:
// 1. total coin market cap ovet time
// 2. a list of coins
// 3. the market cap of those coins over

// what we do with that data:
// * convert the coin market caps of each coin into a dominance %
// * calculate the time since the last the coin last hit peak dominance
// * multiply the dominance % by the time since the last peak
// * sort the coins in descending order of the product of the dominance % and the time since the last peak

#r "nuget: FSharp.Data"
#r "nuget: Microsoft.Data.Analysis"

open FSharp.Data

type BinanceExchangeInfo = JsonProvider<"https://api.binance.com/api/v3/exchangeInfo">
type PriceStream = JsonProvider<"https://api.binance.com/api/v3/klines?symbol=1INCHDOWNUSDT&interval=1d">
type CoinGecko = JsonProvider<"https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=250&page=1&sparkline=false">

let show a =
    printf "%A\n" a

type MarketCap = 
    { Symbol: string
    ; MarketCap: int64
    ; Rank: int }

let gecko = CoinGecko.Load("https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&order=market_cap_desc&per_page=250&page=1&sparkline=false")
let geckoSub =
    gecko
    |> Array.map (fun x -> { Symbol = x.Symbol; MarketCap = x.MarketCap; Rank = x.MarketCapRank })

show geckoSub

let exchInfo = BinanceExchangeInfo.Load("https://api.binance.com/api/v3/exchangeInfo")

let assets = 
    exchInfo.Symbols 
    |> Array.filter (fun x-> x.QuoteAsset.IndexOf("USDT") <> -1 )
    |> Array.filter (fun x-> x.BaseAsset.IndexOf("UP") = -1 && x.BaseAsset.IndexOf("DOWN") = -1) 
    |> Array.map (fun x -> x.Symbol) 
    |> Array.sort
    //|> Array.take 20

type Candle = 
    { Time : uint64
    ; Open : decimal
    ; High:  decimal
    ; Low : decimal
    ; Close: decimal }
    
let makeCandle (assetRow:(decimal array)) =
    { Time = (uint64)assetRow.[0]
    ; Open = assetRow.[1]
    ; High = assetRow.[2]
    ; Low = assetRow.[3]
    ; Close = assetRow.[4] }

let assetHistory symbol (limit:uint64) =
    PriceStream.Load("https://api.binance.com/api/v3/klines?symbol=" + symbol + "&interval=1d&limit=" + limit.ToString())
    |> Array.map makeCandle

let ethHistory = 
    assetHistory "ETHUSDT" 1000UL

let ethPricedAssetHistory limit symbol = 
    let asset = assetHistory symbol limit
    let eth = 
        ethHistory
        |> Array.skip (ethHistory.Length - asset.Length)

    asset
    |> Array.zip eth
    |> Array.map (fun (ethRow, assetRow) -> 
        { Time = assetRow.Time
        ; Open = assetRow.Open / ethRow.Open
        ; High = assetRow.High / ethRow.High
        ; Low = assetRow.Low / ethRow.Low
        ; Close = assetRow.Close / ethRow.Close })

let ath assetHistory = 
    assetHistory 
    |> Array.maxBy (fun x -> x.High)

let timeSinceLastAth now assetHistory =
    let lastAth = (ath assetHistory).Time
    now - lastAth

let daysSinceLastAth now assetHistory =
    (timeSinceLastAth now assetHistory) / (24UL * 60UL * 60UL) / 1000UL

"BTCUSDT" |> (ethPricedAssetHistory 1000UL) |> (daysSinceLastAth ethHistory.[ethHistory.Length - 1].Time)

type assetAthDays = 
    { Asset: string
    ; MarketCap: int64
    ; Rank: int
    ; DaysSinceLastAth: uint64
    ; Order: float }

let allDaysSinceLastAth limit assetList = 
    assetList
    |> Array.Parallel.map (fun (asset:string) -> 
        show asset

        let ast = asset.Replace("USDT", "").ToLowerInvariant()
        
        let cap = 
            geckoSub 
            |> Array.filter (fun x -> x.Symbol = ast.ToLowerInvariant())
            |> Array.sumBy (fun x -> x.MarketCap)

        let rank = 
            geckoSub 
            |> Array.filter (fun x -> x.Symbol = ast.ToLowerInvariant())
            |> Array.sumBy (fun x -> x.Rank)

        let dsath = 
            asset 
            |> ethPricedAssetHistory limit 
            |> daysSinceLastAth ethHistory.[ethHistory.Length - 1].Time

        let order = 
            // ((float(dsath) + 1.0) * Math.Sqrt(float(cap) + 1.0))
            (float(dsath) + 1.0) / float(rank) 

        { Asset = ast
        ; MarketCap = cap
        ; Rank = rank
        ; DaysSinceLastAth = dsath
        ; Order = order })

assets  
|> Array.take assets.Length
|> allDaysSinceLastAth 1000UL
|> Array.filter (fun x -> x.MarketCap <> 0L)
|> Array.sortBy (fun x -> x.Order)
//|> Array.skip 20
// Out:
// <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>FSharp.Data, 4.2.3</span></li><li><span>Microsoft.Data.Analysis, 0.18.0</span></li></ul></div></div>
// [|{ Symbol = "btc"
//     MarketCap = 901150900603L
//     Rank = 1 }; { Symbol = "eth"
//                   MarketCap = 400240278830L
//                   Rank = 2 }; { Symbol = "ada"
//                                 MarketCap = 71694879527L
//                                 Rank = 3 }; { Symbol = "usdt"
//                                               MarketCap = 68822199463L
//                                               Rank = 4 };
//   { Symbol = "bnb"
//     MarketCap = 66138980067L
//     Rank = 5 }; { Symbol = "sol"
//                   MarketCap = 50350550814L
//                   Rank = 6 }; { Symbol = "xrp"
//                                 MarketCap = 49012608531L
//                                 Rank = 7 }; { Symbol = "dot"
//                                               MarketCap = 32928471558L
//                                               Rank = 8 };
//   { Symbol = "usdc"
//     MarketCap = 32124912433L
//     Rank = 9 }; { Symbol = "doge"
//                   MarketCap = 28816419667L
//                   Rank = 10 }; { Symbol = "luna"
//                                  MarketCap = 17002374035L
//                                  Rank = 11 }; { Symbol = "AVAX"
//                                                 MarketCap = 15065911691L
//                                                 Rank = 12 };
//   { Symbol = "uni"
//     MarketCap = 13422403746L
//     Rank = 13 }; { Symbol = "busd"
//                    MarketCap = 13012538721L
//                    Rank = 14 }; { Symbol = "link"
//                                   MarketCap = 12456126652L
//                                   Rank = 15 }; { Symbol = "algo"
//                                                  MarketCap = 11751760249L
//                                                  Rank = 16 };
//   { Symbol = "ltc"
//     MarketCap = 11660622311L
//     Rank = 17 }; { Symbol = "atom"
//                    MarketCap = 10766287380L
//                    Rank = 18 }; { Symbol = "bch"
//                                   MarketCap = 10690222756L
//                                   Rank = 19 }; { Symbol = "wbtc"
//                                                  MarketCap = 9898741269L
//                                                  Rank = 20 };
//   { Symbol = "matic"
//     MarketCap = 8656749113L
//     Rank = 21 }; { Symbol = "icp"
//                    MarketCap = 8280266167L
//                    Rank = 22 }; { Symbol = "axs"
//                                   MarketCap = 7811254053L
//                                   Rank = 23 }; { Symbol = "fil"
//                                                  MarketCap = 7526207015L
//                                                  Rank = 24 };
//   { Symbol = "xlm"
//     MarketCap = 7446956880L
//     Rank = 25 }; { Symbol = "vet"
//                    MarketCap = 7361095770L
//                    Rank = 26 }; { Symbol = "xtz"
//                                   MarketCap = 7237608045L
//                                   Rank = 27 }; { Symbol = "etc"
//                                                  MarketCap = 6943606360L
//                                                  Rank = 28 };
//   { Symbol = "ftt"
//     MarketCap = 6822120403L
//     Rank = 29 }; { Symbol = "trx"
//                    MarketCap = 6765364619L
//                    Rank = 30 }; { Symbol = "dai"
//                                   MarketCap = 6202333839L
//                                   Rank = 31 }; { Symbol = "theta"
//                                                  MarketCap = 6062227268L
//                                                  Rank = 32 };
//   { Symbol = "ceth"
//     MarketCap = 5926090454L
//     Rank = 33 }; { Symbol = "egld"
//                    MarketCap = 4891604037L
//                    Rank = 34 }; { Symbol = "okb"
//                                   MarketCap = 4772249001L
//                                   Rank = 35 }; { Symbol = "xmr"
//                                                  MarketCap = 4604246807L
//                                                  Rank = 36 };
//   { Symbol = "xec"
//     MarketCap = 4600438561L
//     Rank = 37 }; { Symbol = "cro"
//                    MarketCap = 4530303715L
//                    Rank = 38 }; { Symbol = "steth"
//                                   MarketCap = 4514658954L
//                                   Rank = 39 }; { Symbol = "eos"
//                                                  MarketCap = 4480158598L
//                                                  Rank = 40 };
//   { Symbol = "cake"
//     MarketCap = 4468895213L
//     Rank = 41 }; { Symbol = "qnt"
//                    MarketCap = 4272805575L
//                    Rank = 42 }; { Symbol = "shib"
//                                   MarketCap = 4116716278L
//                                   Rank = 43 }; { Symbol = "aave"
//                                                  MarketCap = 4088688809L
//                                                  Rank = 44 };
//   { Symbol = "hbar"
//     MarketCap = 4057333903L
//     Rank = 45 }; { Symbol = "bcha"
//                    MarketCap = 3969597532L
//                    Rank = 46 }; { Symbol = "near"
//                                   MarketCap = 3747913274L
//                                   Rank = 47 }; { Symbol = "ftm"
//                                                  MarketCap = 3699126712L
//                                                  Rank = 48 };
//   { Symbol = "grt"
//     MarketCap = 3583906577L
//     Rank = 49 }; { Symbol = "miota"
//                    MarketCap = 3504748691L
//                    Rank = 50 }; { Symbol = "neo"
//                                   MarketCap = 3098296645L
//                                   Rank = 51 }; { Symbol = "ksm"
//                                                  MarketCap = 3084705956L
//                                                  Rank = 52 };
//   { Symbol = "klay"
//     MarketCap = 3071373105L
//     Rank = 53 }; { Symbol = "cusdc"
//                    MarketCap = 2920415791L
//                    Rank = 54 }; { Symbol = "leo"
//                                   MarketCap = 2767320059L
//                                   Rank = 55 }; { Symbol = "bsv"
//                                                  MarketCap = 2710109855L
//                                                  Rank = 56 };
//   { Symbol = "waves"
//     MarketCap = 2707917849L
//     Rank = 57 }; { Symbol = "ust"
//                    MarketCap = 2680369133L
//                    Rank = 58 }; { Symbol = "cdai"
//                                   MarketCap = 2617411612L
//                                   Rank = 59 }; { Symbol = "cel"
//                                                  MarketCap = 2412860446L
//                                                  Rank = 60 };
//   { Symbol = "ar"
//     MarketCap = 2366437739L
//     Rank = 61 }; { Symbol = "amp"
//                    MarketCap = 2338431130L
//                    Rank = 62 }; { Symbol = "btt"
//                                   MarketCap = 2315777129L
//                                   Rank = 63 }; { Symbol = "mkr"
//                                                  MarketCap = 2263351321L
//                                                  Rank = 64 };
//   { Symbol = "rune"
//     MarketCap = 2261724374L
//     Rank = 65 }; { Symbol = "omg"
//                    MarketCap = 2244720307L
//                    Rank = 66 }; { Symbol = "sushi"
//                                   MarketCap = 2072069147L
//                                   Rank = 67 }; { Symbol = "hnt"
//                                                  MarketCap = 2068613011L
//                                                  Rank = 68 };
//   { Symbol = "celo"
//     MarketCap = 2037830519L
//     Rank = 69 }; { Symbol = "comp"
//                    MarketCap = 1962160980L
//                    Rank = 70 }; { Symbol = "one"
//                                   MarketCap = 1954153739L
//                                   Rank = 71 }; { Symbol = "hbtc"
//                                                  MarketCap = 1911114079L
//                                                  Rank = 72 };
//   { Symbol = "ohm"
//     MarketCap = 1907818176L
//     Rank = 73 }; { Symbol = "snx"
//                    MarketCap = 1866406830L
//                    Rank = 74 }; { Symbol = "dash"
//                                   MarketCap = 1825356553L
//                                   Rank = 75 }; { Symbol = "hot"
//                                                  MarketCap = 1631313384L
//                                                  Rank = 76 };
//   { Symbol = "xdc"
//     MarketCap = 1604789262L
//     Rank = 77 }; { Symbol = "tfuel"
//                    MarketCap = 1601376098L
//                    Rank = 78 }; { Symbol = "dcr"
//                                   MarketCap = 1584963568L
//                                   Rank = 79 }; { Symbol = "chz"
//                                                  MarketCap = 1514995404L
//                                                  Rank = 80 };
//   { Symbol = "xem"
//     MarketCap = 1457339491L
//     Rank = 81 }; { Symbol = "deso"
//                    MarketCap = 1451941940L
//                    Rank = 82 }; { Symbol = "icx"
//                                   MarketCap = 1429598237L
//                                   Rank = 83 }; { Symbol = "enj"
//                                                  MarketCap = 1412731064L
//                                                  Rank = 84 };
//   { Symbol = "qtum"
//     MarketCap = 1381902719L
//     Rank = 85 }; { Symbol = "stx"
//                    MarketCap = 1374705823L
//                    Rank = 86 }; { Symbol = "zec"
//                                   MarketCap = 1358127110L
//                                   Rank = 87 }; { Symbol = "tusd"
//                                                  MarketCap = 1342928674L
//                                                  Rank = 88 };
//   { Symbol = "ht"
//     MarketCap = 1334365956L
//     Rank = 89 }; { Symbol = "omi"
//                    MarketCap = 1307407709L
//                    Rank = 90 }; { Symbol = "iost"
//                                   MarketCap = 1259911732L
//                                   Rank = 91 }; { Symbol = "zil"
//                                                  MarketCap = 1239043762L
//                                                  Rank = 92 };
//   { Symbol = "flow"
//     MarketCap = 1222496915L
//     Rank = 93 }; { Symbol = "srm"
//                    MarketCap = 1175798731L
//                    Rank = 94 }; { Symbol = "mina"
//                                   MarketCap = 1138176634L
//                                   Rank = 95 }; { Symbol = "dydx"
//                                                  MarketCap = 1131470930L
//                                                  Rank = 96 };
//   { Symbol = "crv"
//     MarketCap = 1122516945L
//     Rank = 97 }; { Symbol = "yfi"
//                    MarketCap = 1117784177L
//                    Rank = 98 }; { Symbol = "rvn"
//                                   MarketCap = 1073495762L
//                                   Rank = 99 }; { Symbol = "bat"
//                                                  MarketCap = 1069050297L
//                                                  Rank = 100 }; ...|]
// "1INCHUSDT"
// "BEARUSDT"
// "EGLDUSDT"
// "FIOUSDT"
// "KEEPUSDT"
// "NMRUSDT"
// "ROSEUSDT"
// "ATOMUSDT"
// "DAIUSDT"
// "MATICUSDT"
// "STRAXUSDT"
// "HARDUSDT"
// "C98USDT"
// "PHAUSDT"
// "AAVEUSDT"
// "WAVESUSDT"
// "AUDIOUSDT"
// "CAKEUSDT"
// "DASHUSDT"
// "HBARUSDT"
// "MBLUSDT"
// "YFIIUSDT"
// "TRXUSDT"
// "FIROUSDT"
// "NPXSUSDT"
// "ELFUSDT"
// "BELUSDT"
// "KEYUSDT"
// "WAXPUSDT"
// "PNTUSDT"
// "TUSDUSDT"
// "STXUSDT"
// "YFIUSDT"
// "RSRUSDT"
// "ACMUSDT"
// "AUDUSDT"
// "BKRWUSDT"
// "CELOUSDT"
// "DATAUSDT"
// "ENJUSDT"
// "FISUSDT"
// "HCUSDT"
// "KLAYUSDT"
// "MBOXUSDT"
